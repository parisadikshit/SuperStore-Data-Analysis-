# %% [markdown]
# # 1.Identifying and Importing Essential Libraries

# %%
# Importing necessary modules for data analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # 2. Data loading and overview

# %%
data = pd.read_csv('./Superstore.csv')

# %%
# first 5 records
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   8/11/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   8/11/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   12/6/2016   16/6/2016    Second Class    DV-13045
# 3       4  US-2015-108966  11/10/2015  18/10/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  11/10/2015  18/10/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# printing the columns in the data
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# showing the attributes like count, mean, varaince and standard deviation
data.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
# finding out if there are any missing or null values in data 
data.isnull()
# Out:
#       Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0      False     False       False      False      False        False
# 1      False     False       False      False      False        False
# 2      False     False       False      False      False        False
# 3      False     False       False      False      False        False
# 4      False     False       False      False      False        False
# ...      ...       ...         ...        ...        ...          ...
# 9989   False     False       False      False      False        False
# 9990   False     False       False      False      False        False
# 9991   False     False       False      False      False        False
# 9992   False     False       False      False      False        False
# 9993   False     False       False      False      False        False
#
#       Customer Name  Segment  Country   City  ...  Postal Code  Region  \
# ...

# %%
# taking count of missing values in respective columns if the null or missing values exist
data.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# # 3. Find out the per unit price from the data --A

# %%
# converting date time field into pandas object
data['Ship Date'] = pd.to_datetime(data['Ship Date'])
data['Order Date'] = pd.to_datetime(data['Order Date'])

# %% [markdown]
# Cost Per Item Purchased = Selling Price per Item - Profit per Item

# %%
# cost price = selling price - profit
data['Price per unit'] = ((data['Sales']/data['Quantity']))-((data['Profit']/data['Quantity'])) 
# Column 'Price per unit' is added at the end

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-08-11 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-08-11 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-12-06 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-11-10 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-11-10 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# # 4.Find out the monthly revenue and analyze the findings

# %%
data.set_index(data['Ship Date'])
# Out:
#             Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# Ship Date
# 2016-11-11       1  CA-2016-152156 2016-08-11 2016-11-11    Second Class
# 2016-11-11       2  CA-2016-152156 2016-08-11 2016-11-11    Second Class
# 2016-06-16       3  CA-2016-138688 2016-12-06 2016-06-16    Second Class
# 2015-10-18       4  US-2015-108966 2015-11-10 2015-10-18  Standard Class
# 2015-10-18       5  US-2015-108966 2015-11-10 2015-10-18  Standard Class
# ...            ...             ...        ...        ...             ...
# 2014-01-23    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 2017-03-03    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 2017-03-03    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 2017-03-03    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 2017-09-05    9994  CA-2017-119914 2017-04-05 2017-09-05    Second Class
#
#            Customer ID     Customer Name    Segment        Country  \
# ...

# %%
data['Month']=0
data['Year']=0
# initially the data

# %%
# 2 new columns were created 
for i in range(len(data['Row ID'])):
    data['Month'][i]=data['Ship Date'][i].month
    data['Year'][i]=data['Ship Date'][i].year
# Out:
# /home/shreya/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/shreya/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-08-11 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-08-11 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-12-06 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-11-10 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-11-10 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#           Category  Sub-Category  \
# 0        Furniture     Bookcases
# 1        Furniture        Chairs
# ...

# %%
data_yearly = data.groupby('Year')

# %%
data_yearly_year_2014 = data_yearly.get_group(2014)
data_yearly_year_2014.shape
# Out:
# (1940, 24)

# %%
data_yearly_year_2015 = data_yearly.get_group(2015)
data_yearly_year_2015.shape
# Out:
# (2131, 24)

# %%
data_yearly_year_2016 = data_yearly.get_group(2016)
data_yearly_year_2016.shape
# Out:
# (2578, 24)

# %%
data_yearly_year_2017 = data_yearly.get_group(2017)
data_yearly_year_2017.shape
# Out:
# (3303, 24)

# %%
data_yearly_year_2018 = data_yearly.get_group(2018)
data_yearly_year_2018.shape
# Out:
# (42, 24)

# %%
sales_month  = data[['Month','Sales','Year']]
sales_month.set_index(['Month','Year'])
# Out:
#                Sales
# Month Year
# 11    2016  261.9600
#       2016  731.9400
# 6     2016   14.6200
# 10    2015  957.5775
#       2015   22.3680
# ...              ...
# 1     2014   25.2480
# 3     2017   91.9600
#       2017  258.5760
#       2017   29.6000
# 9     2017  243.1600
#
# [9994 rows x 1 columns]

# %%
month=[]
yearss=[]
salesmonthyear=[]
data_month = sales_month.groupby(['Month','Year'])
for m,df in data_month:
    month.append(m[0])
    yearss.append(m[1])
    salesmonthyear.append(df['Sales'].sum())

# %%
salemonthyeardf = pd.DataFrame({'Month':month,'Year':yearss,'Sales':salesmonthyear})
salemonthyeardf.head()
# Out:
#    Month  Year       Sales
# 0      1  2014  18304.8910
# 1      1  2015  28538.5800
# 2      1  2016  26419.8815
# 3      1  2017  48208.5306
# 4      1  2018   2390.1548

# %%
sns.scatterplot(x=salemonthyeardf['Month'],y=salemonthyeardf['Sales'],hue=salemonthyeardf['Year'])

# %%
sns.barplot(x=salemonthyeardf['Month'],y=salemonthyeardf['Sales'],hue=salemonthyeardf['Year'])

# %% [markdown]
# After plotting the monthly data(considering the year), In 2014, in **September**, the revenue collected is highest and the least is in february. In 2015, the revenue in the month of **December** is highest while in february is the lowest.In 2016, the revenue collected in the month of **September** is highest,in 2017, the revenue is highest in **December** and in 2018, the revenue is highest in **January**
#
# ''**In every year, in month of FEBRUARY the revenue seems to drop in comparison to other months**''

# %% [markdown]
# #  5.Find out the yearly revenue and analyze the findings

# %%
# now grouping data by year
sales_year  = data[['Year','Sales']]
sales_year.set_index('Year')
# Out:
#          Sales
# Year
# 2016  261.9600
# 2016  731.9400
# 2016   14.6200
# 2015  957.5775
# 2015   22.3680
# ...        ...
# 2014   25.2480
# 2017   91.9600
# 2017  258.5760
# 2017   29.6000
# 2017  243.1600
#
# [9994 rows x 1 columns]

# %%
year = []
salesyear=[]
data_yearly = data.groupby('Year')
for y,df in data_yearly:
    year.append(y)
    salesyear.append(df['Sales'].sum())# so there is info of 5 years

# %%
sales_year_df = pd.DataFrame({'Year':year,'Sales':salesyear})
sales_year_df.head()
# Out:
#    Year        Sales
# 0  2014  470383.1931
# 1  2015  479442.5020
# 2  2016  611325.7530
# 3  2017  730889.7154
# 4  2018    5159.6968

# %%
plt.bar(sales_year_df['Year'],sales_year_df['Sales'])
plt.xlabel('Years')
plt.ylabel('Sales')
plt.show('Yearly Revenue')
plt.show()

# %% [markdown]
# **From yearly study of revenue, it can be seen that the sales grew higher from 2014 till 2017 andthe sales were highest in 2017 and then suddenly dropped in 2018**

# %% [markdown]
# # 7.Finding out the most and least sold product id

# %%
d_prodid_quantity = data[['Product ID','Quantity']]
d_prodid_quantity.set_index('Product ID')
# Out:
#                  Quantity
# Product ID
# FUR-BO-10001798         2
# FUR-CH-10000454         3
# OFF-LA-10000240         2
# FUR-TA-10000577         5
# OFF-ST-10000760         2
# ...                   ...
# FUR-FU-10001889         3
# FUR-FU-10000747         2
# TEC-PH-10003645         2
# OFF-PA-10004041         4
# OFF-AP-10002684         2
#
# [9994 rows x 1 columns]

# %%
d_prod_id_quantity_group = d_prodid_quantity.groupby('Product ID')

# %%
prodid=[]
quantity=[]
for prod_id,df in d_prod_id_quantity_group:
    prodid.append(prod_id)
    quantity.append(df['Quantity'].sum())

# %%
d_prod_quanty = pd.DataFrame({'Product ID':prodid,'Quantity':quantity})

# %%
d_prod_quanty
# Out:
#            Product ID  Quantity
# 0     FUR-BO-10000112         9
# 1     FUR-BO-10000330        10
# 2     FUR-BO-10000362        14
# 3     FUR-BO-10000468        21
# 4     FUR-BO-10000711        12
# ...               ...       ...
# 1857  TEC-PH-10004912        11
# 1858  TEC-PH-10004922        19
# 1859  TEC-PH-10004924         8
# 1860  TEC-PH-10004959         4
# 1861  TEC-PH-10004977        32
#
# [1862 rows x 2 columns]

# %%
d_prod_quanty['Quantity'].max()
# Out:
# 75

# %%
d_prod_quanty['Quantity'].min()
# Out:
# 1

# %%
d_prod_quanty[d_prod_quanty['Quantity']==75]
# Out:
#            Product ID  Quantity
# 1569  TEC-AC-10003832        75

# %%
d_prod_quanty[d_prod_quanty['Quantity']==1]
# Out:
#            Product ID  Quantity
# 17    FUR-BO-10002206         1
# 86    FUR-CH-10002317         1
# 558   OFF-AR-10002704         1
# 1016  OFF-PA-10000048         1
# 1661  TEC-MA-10003493         1

# %% [markdown]
# # 8.Finding out the customer who bought most and least from us in terms of quantity

# %%
# creating a dataset of customer names and quantities they bought
dnew_quantity = data[['Customer Name','Quantity']]
dnew_quantity.set_index('Customer Name')
# Out:
#                   Quantity
# Customer Name
# Claire Gute              2
# Claire Gute              3
# Darrin Van Huff          2
# Sean O'Donnell           5
# Sean O'Donnell           2
# ...                    ...
# Tom Boeckenhauer         3
# Dave Brooks              2
# Dave Brooks              2
# Dave Brooks              4
# Chris Cortes             2
#
# [9994 rows x 1 columns]

# %%
dnew_quantity_group = dnew_quantity.groupby('Customer Name')

# %%
customer_name_=[]
quantity=[]
for customer_name,df in dnew_quantity_group:
    customer_name_.append(customer_name)
    quantity.append(df['Quantity'].sum())

# %%
# new dataset with customer name and quantity
new_df = pd.DataFrame({'Customer Name':customer_name_,'Total Quantity':quantity})

# %%
new_df
# Out:
#           Customer Name  Total Quantity
# 0         Aaron Bergman              13
# 1         Aaron Hawkins              54
# 2        Aaron Smayling              48
# 3       Adam Bellavance              56
# 4             Adam Hart              75
# ..                  ...             ...
# 788        Xylona Preis             100
# 789       Yana Sorensen              58
# 790      Yoseph Carroll              31
# 791    Zuschuss Carroll             105
# 792  Zuschuss Donatelli              32
#
# [793 rows x 2 columns]

# %%
new_df[new_df['Customer Name']=='Claire Gute']
# Out:
#     Customer Name  Total Quantity
# 166   Claire Gute              14

# %%
# just confirming if there are really 14 purchased items by Claire Gute
data[data['Customer Name']=='Claire Gute']
# Out:
#       Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0          1  CA-2016-152156 2016-08-11 2016-11-11  Second Class    CG-12520
# 1          2  CA-2016-152156 2016-08-11 2016-11-11  Second Class    CG-12520
# 5491    5492  CA-2017-164098 2017-01-26 2017-01-27   First Class    CG-12520
# 6877    6878  US-2015-123918 2015-10-15 2015-10-15      Same Day    CG-12520
# 6878    6879  US-2015-123918 2015-10-15 2015-10-15      Same Day    CG-12520
#
#      Customer Name   Segment        Country       City  ...         Category  \
# 0      Claire Gute  Consumer  United States  Henderson  ...        Furniture
# 1      Claire Gute  Consumer  United States  Henderson  ...        Furniture
# 5491   Claire Gute  Consumer  United States    Houston  ...  Office Supplies
# 6877   Claire Gute  Consumer  United States     Dallas  ...        Furniture
# 6878   Claire Gute  Consumer  United States     Dallas  ...  Office Supplies
#
# ...

# %%
new_df.describe()
# Out:
#        Total Quantity
# count      793.000000
# mean        47.759142
# std         24.842915
# min          2.000000
# 25%         30.000000
# 50%         44.000000
# 75%         63.000000
# max        150.000000

# %%
# the person who bought least in quantity 
new_df[new_df['Total Quantity']==2]
# Out:
#         Customer Name  Total Quantity
# 53  Anthony O'Donnell               2

# %%
# the person who bought most in quantity 
new_df[new_df['Total Quantity']==150]
# Out:
#         Customer Name  Total Quantity
# 391  Jonathan Doherty             150

# %% [markdown]
# #  9.Finding out the customer who bought most and least from us in terms of value

# %%
dnew_sales = data[['Customer Name','Sales']]
dnew_sales.set_index('Customer Name')
# Out:
#                      Sales
# Customer Name
# Claire Gute       261.9600
# Claire Gute       731.9400
# Darrin Van Huff    14.6200
# Sean O'Donnell    957.5775
# Sean O'Donnell     22.3680
# ...                    ...
# Tom Boeckenhauer   25.2480
# Dave Brooks        91.9600
# Dave Brooks       258.5760
# Dave Brooks        29.6000
# Chris Cortes      243.1600
#
# [9994 rows x 1 columns]

# %%
dnew_sales_group = dnew_sales.groupby('Customer Name')

# %%
customer_names=[]
total_sales = []
for customer_name, df in dnew_sales_group:
    customer_names.append(customer_name)
    total_sales.append(df['Sales'].sum())

# %%
new_df_sales = pd.DataFrame({'Customer Names':customer_names,'Total Sale':total_sales})

# %%
new_df_sales
# Out:
#          Customer Names  Total Sale
# 0         Aaron Bergman     886.156
# 1         Aaron Hawkins    1744.700
# 2        Aaron Smayling    3050.692
# 3       Adam Bellavance    7755.620
# 4             Adam Hart    3250.337
# ..                  ...         ...
# 788        Xylona Preis    2374.658
# 789       Yana Sorensen    6720.444
# 790      Yoseph Carroll    5454.350
# 791    Zuschuss Carroll    8025.707
# 792  Zuschuss Donatelli    1493.944
#
# [793 rows x 2 columns]

# %%
new_df_sales['Total Sale'].max()
# Out:
# 25043.05

# %%
new_df_sales['Total Sale'].min()
# Out:
# 4.833

# %%
# the person with highest purchase

new_df_sales[new_df_sales['Total Sale']==25043.05]
# Out:
#     Customer Names  Total Sale
# 686    Sean Miller    25043.05

# %%
# the person with least purchase
new_df_sales[new_df_sales['Total Sale']==4.833]
# Out:
#     Customer Names  Total Sale
# 737  Thais Sissman       4.833

# %% [markdown]
# # 10. Finding out the majority and minority customer cities on basis of --A

# %% [markdown]
# # Number of customers

# %%
dncustomer = data[['Customer Name','City']]
dncustomer.set_index('City')
# Out:
#                     Customer Name
# City
# Henderson             Claire Gute
# Henderson             Claire Gute
# Los Angeles       Darrin Van Huff
# Fort Lauderdale    Sean O'Donnell
# Fort Lauderdale    Sean O'Donnell
# ...                           ...
# Miami            Tom Boeckenhauer
# Costa Mesa            Dave Brooks
# Costa Mesa            Dave Brooks
# Costa Mesa            Dave Brooks
# Westminster          Chris Cortes
#
# [9994 rows x 1 columns]

# %%
dncustomercitygroup = dncustomer.groupby('City')
city = []
custnum = []
for name,df in dncustomercitygroup:
    city.append(name)
    custnum.append(len(df['Customer Name']))

# %%
dncustomercitydf = pd.DataFrame({'City':city,'Number of Customers':custnum})
dncustomercitydf.head()
# Out:
#           City  Number of Customers
# 0     Aberdeen                    1
# 1      Abilene                    1
# 2        Akron                   21
# 3  Albuquerque                   14
# 4   Alexandria                   16

# %% [markdown]
# >> There are most customers from Alexandria who purchase and least from Aberdeen and Abilene

# %% [markdown]
# # Sales Value

# %%
dnsalescity = data[['City','Sales']]
dnsalescity.set_index('City')
# Out:
#                     Sales
# City
# Henderson        261.9600
# Henderson        731.9400
# Los Angeles       14.6200
# Fort Lauderdale  957.5775
# Fort Lauderdale   22.3680
# ...                   ...
# Miami             25.2480
# Costa Mesa        91.9600
# Costa Mesa       258.5760
# Costa Mesa        29.6000
# Westminster      243.1600
#
# [9994 rows x 1 columns]

# %%
dnsales_per_citygroup = dnsalescity.groupby('City')
salescity = []
for name,df in dnsales_per_citygroup:
    salescity.append(df['Sales'].sum())

# %%
dnsales_per_citydf = pd.DataFrame({'City':city,'Sales Generated':salescity})
dnsales_per_citydf.head()
# Out:
#           City  Sales Generated
# 0     Aberdeen           25.500
# 1      Abilene            1.392
# 2        Akron         2729.986
# 3  Albuquerque         2220.160
# 4   Alexandria         5519.570

# %% [markdown]
# >> Sales are most from Alexandria and least from Abeilene city

# %% [markdown]
# # Number of quantity sold

# %%
dnquancity = data[['City','Quantity']]
dnquancity.set_index('City')
# Out:
#                  Quantity
# City
# Henderson               2
# Henderson               3
# Los Angeles             2
# Fort Lauderdale         5
# Fort Lauderdale         2
# ...                   ...
# Miami                   3
# Costa Mesa              2
# Costa Mesa              2
# Costa Mesa              4
# Westminster             2
#
# [9994 rows x 1 columns]

# %%
dnquan_per_citygroup = dnquancity.groupby('City')
quancity = []
for name,df in dnquan_per_citygroup:
    quancity.append(df['Quantity'].sum())

# %%
dnquan_per_citydf = pd.DataFrame({'City':city,'Quantity Sold':quancity})
dnquan_per_citydf.head()
# Out:
#           City  Quantity Sold
# 0     Aberdeen              3
# 1      Abilene              2
# 2        Akron             65
# 3  Albuquerque             65
# 4   Alexandria             84

# %% [markdown]
# The quantity of products getting sold in Alexandria is highest and lowest in Aberdeen

# %% [markdown]
# # 11.Find out the most and least sold product category from the store

# %% [markdown]
# #   Value Based:

# %%
dncat_sales = data[['Category','Sales']]
dncat_sales.set_index('Category')
# Out:
#                     Sales
# Category
# Furniture        261.9600
# Furniture        731.9400
# Office Supplies   14.6200
# Furniture        957.5775
# Office Supplies   22.3680
# ...                   ...
# Furniture         25.2480
# Furniture         91.9600
# Technology       258.5760
# Office Supplies   29.6000
# Office Supplies  243.1600
#
# [9994 rows x 1 columns]

# %%
dncat_sales_group = dncat_sales.groupby('Category')

# %%
cat=[]
catsales=[]
for cat_,df in dncat_sales_group:
    cat.append(cat_)
    catsales.append(df['Sales'].sum())

# %%
dncat_sales_data = pd.DataFrame({'Category':cat,'Sales':catsales})

# %%
dncat_sales_data
# Out:
#           Category        Sales
# 0        Furniture  741999.7953
# 1  Office Supplies  719047.0320
# 2       Technology  836154.0330

# %% [markdown]
# **Most sold product categories based on sales are Technology and least is Office Supplies**

# %% [markdown]
# #   Quantity Based:

# %%
dncat_quan = data[['Category','Quantity']]
dncat_quan.set_index('Category')
# Out:
#                  Quantity
# Category
# Furniture               2
# Furniture               3
# Office Supplies         2
# Furniture               5
# Office Supplies         2
# ...                   ...
# Furniture               3
# Furniture               2
# Technology              2
# Office Supplies         4
# Office Supplies         2
#
# [9994 rows x 1 columns]

# %%
dncat_quan_group = dncat_quan.groupby('Category')
category=[]
catquan=[]
for cat_,df in dncat_quan_group:
    category.append(cat_)
    catquan.append(df['Quantity'].sum())

# %%
dncat_quan_data = pd.DataFrame({'Category':category,'Quantity':catquan})

# %%
dncat_quan_data
# Out:
#           Category  Quantity
# 0        Furniture      8028
# 1  Office Supplies     22906
# 2       Technology      6939

# %% [markdown]
# >> by seeing we can see that **technology products are least sold** and **office supplies are most sold**

# %% [markdown]
# # 12. Find out the most and least sold product sub category from the store

# %% [markdown]
# # Value based:

# %%
dnsub_sales = data[['Sub-Category','Sales']]
dnsub_sales.set_index('Sub-Category')
# Out:
#                  Sales
# Sub-Category
# Bookcases     261.9600
# Chairs        731.9400
# Labels         14.6200
# Tables        957.5775
# Storage        22.3680
# ...                ...
# Furnishings    25.2480
# Furnishings    91.9600
# Phones        258.5760
# Paper          29.6000
# Appliances    243.1600
#
# [9994 rows x 1 columns]

# %%
dnsub_sales_group = dnsub_sales.groupby('Sub-Category')
subcat = []
subsales = []
for cat, df in dnsub_sales_group:
    subcat.append(cat)
    subsales.append(df['Sales'].sum())

# %%
dnsub_sales_df = pd.DataFrame({'Sub-Category':subcat,'Sales':subsales})
dnsub_sales_df.head()
# Out:
#   Sub-Category        Sales
# 0  Accessories  167380.3180
# 1   Appliances  107532.1610
# 2          Art   27118.7920
# 3      Binders  203412.7330
# 4    Bookcases  114879.9963

# %% [markdown]
# By seeing,it can be seen that **the sub category that brought most of sales is Binders** and **least is from Art**

# %% [markdown]
# # Quantity based:

# %%
dnsub_quantity = data[['Sub-Category','Quantity']]
dnsub_quantity.set_index('Sub-Category')
# Out:
#               Quantity
# Sub-Category
# Bookcases            2
# Chairs               3
# Labels               2
# Tables               5
# Storage              2
# ...                ...
# Furnishings          3
# Furnishings          2
# Phones               2
# Paper                4
# Appliances           2
#
# [9994 rows x 1 columns]

# %%
dnsub_quantity_group = dnsub_quantity.groupby('Sub-Category')
subquan=[]
for cat,df in dnsub_quantity_group:
    subquan.append(df['Quantity'].sum())

# %%
dnsub_quantity_df = pd.DataFrame({'Sub-Category':subcat,'Quantity':subquan})
dnsub_quantity_df.head()
# Out:
#   Sub-Category  Quantity
# 0  Accessories      2976
# 1   Appliances      1729
# 2          Art      3000
# 3      Binders      5974
# 4    Bookcases       868

# %% [markdown]
# By seeing we can see that the **most sold sub-category in terms of quantity is Binders** and **least is Appliances**

# %%
#continued
